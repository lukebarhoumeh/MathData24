# %% [markdown]
# <a href="https://colab.research.google.com/github/lukebarhoumeh/MathData24/blob/main/MathData_class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NOTES
# 8.20.24

# %% [markdown]
# <img src="https://c2.staticflickr.com/6/5024/5555927344_3c698e4ee3_b.jpg" width=300>
#
# ```
# # This is formatted as code
# ```

# %%
apples = 10

# %%
oranges = 8

# %%
total = apples + oranges

# %%
total
# Out:
# 18

# %%
print(total) ## alt
# Out:
# 18

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
A = np.random.random()

# %%
A
# Out:
# 0.9553824130834841

# %%
A = np.random.random((1,5))

# %%
A
# Out:
# array([[0.05846316, 0.869132  , 0.05664188, 0.46874673, 0.03490277]])

# %%
B = np.random.random((1,5))

# %%
A= A.T
B= B.T

# %%
A,B
# Out:
# (array([[0.05846316],
#         [0.869132  ],
#         [0.05664188],
#         [0.46874673],
#         [0.03490277]]),
#  array([[0.6172097 ],
#         [0.50396216],
#         [0.14048057],
#         [0.454342  ],
#         [0.91991078]]))

# %%
plt.plot(A,B)

# %%
plt.plot(A,B,'r.')

# %%
X = np.random.random((100,1))
Y = np.random.random((100,1))
plt.plot(X,Y, 'g--')

# %%
A.shape
# Out:
# (5, 1)

# %%
print(B.shape, A.shape, X.shape, Y.shape)
# Out:
# (5, 1) (5, 1) (100, 1) (100, 1)

# %%
Z = np.random.random((100,100))

# %%
Z.shape
# Out:
# (100, 100)

# %%
Z
# Out:
# array([[0.31343933, 0.39113003, 0.43364613, ..., 0.10450497, 0.12491861,
#         0.99249922],
#        [0.34609072, 0.08748095, 0.12894592, ..., 0.48208138, 0.04634198,
#         0.92032054],
#        [0.8402537 , 0.55591324, 0.46063497, ..., 0.46009511, 0.7347217 ,
#         0.24615763],
#        ...,
#        [0.67295347, 0.85582501, 0.83545415, ..., 0.1241453 , 0.90449463,
#         0.05497413],
#        [0.87337236, 0.82040957, 0.18252401, ..., 0.88515433, 0.32416435,
#         0.17283116],
#        [0.87748858, 0.79339331, 0.58462739, ..., 0.97301269, 0.57412889,
#         0.08338773]])

# %%
plt.imshow(Z)

# %%
# Create a 10x10 matrix with random values
matrix = np.random.rand(10, 10)

# Plot the matrix as an image
plt.imshow(matrix, cmap='viridis', interpolation='none')
plt.colorbar()  # Add a colorbar for reference
plt.title("Random 10x10 Matrix")
plt.show()
